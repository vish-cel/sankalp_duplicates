# %%
import pandas as pd

# %%
# Load the first CSV file
df1 = pd.read_csv('NHRPsankalpUpdated-NotificationData_DATA_LABELS_2025-08-19_0843.csv')

# %%
# Load the second CSV file
df2 = pd.read_csv('BirthNotificationBy Asha_2025-08-19.csv')

# %%
# Display the first few rows and information about the first DataFrame
print("DataFrame 1 - NHRPsankalpUpdated-NotificationData_DATA_LABELS_2025-08-19_0843.csv")
print(df1.head())
print(df1.info())
# Out:
# DataFrame 1 - NHRPsankalpUpdated-NotificationData_DATA_LABELS_2025-08-19_0843.csv
#   Record ID Q1. District Name             Q2. Data Collected From  \
# 0     112-1           varansi  Delivery Register (Facility Visit)
# 1     112-2           varansi  Delivery Register (Facility Visit)
# 2     112-3           varansi  Delivery Register (Facility Visit)
# 3     112-4           varansi  Delivery Register (Facility Visit)
# 4     112-5           varansi  Delivery Register (Facility Visit)
#
#   Q3. Name of the facility where the data was collected    \
# 0                                        AAM Rajwari
# 1                                         PHC Pindra
# 2                                     CHC Narpat Pur
# 3                                     CHC Narpat Pur
# 4                                     CHC Narpat Pur
#
#    Q4. Other Facility Name Q7. Call/Visit Date  Call Hour  Call Minute  \
# 0                      NaN          05-03-2025          5         25.0
# 1                      NaN          04-03-2025         10         47.0
# 2                      NaN          04-03-2025         10         46.0
# 3                      NaN          04-03-2025         11         19.0
# 4                      NaN          04-03-2025         11         42.0
#
#   Call Type  Q9. Type of call  ...  \
# 0         PM              NaN  ...
# 1         AM              NaN  ...
# 2         AM              NaN  ...
# 3         AM              NaN  ...
# 4         AM              NaN  ...
#
#   Q56. Baby-2 : Baby Current Status (at the time of notification)    \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Q57. Baby-2 : If died, then Date of death of Newborn (dd/mm/yyyy)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Q59. Baby-3: What was the status of the baby at birth?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Q60. Baby-3 : Sex of the baby  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#   Q61. Baby-3 : Birth weight of the baby (grams)    \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Q62. Baby-3: Baby Current Status (at the time of notification)    \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Q63. Baby-3 : If died, then Date of death of Newborn (dd/mm/yyyy)  BabyAge  \
# 0                                                NaN                        5
# 1                                                NaN                        4
# 2                                                NaN                        4
# 3                                                NaN                        3
# 4                                                NaN                        3
#
#   Q64. Remarks Complete?
# 0          NaN  Complete
# 1          NaN  Complete
# 2          NaN  Complete
# 3          NaN  Complete
# 4          NaN  Complete
#
# [5 rows x 67 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5786 entries, 0 to 5785
# Data columns (total 67 columns):
#  #   Column                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                              --------------  -----
#  0   Record ID                                                                                           5786 non-null   object
#  1   Q1. District Name                                                                                   5786 non-null   object
#  2   Q2. Data Collected From                                                                             5786 non-null   object
#  3   Q3. Name of the facility where the data was collected                                               4556 non-null   object
#  4   Q4. Other Facility Name                                                                             0 non-null      float64
#  5   Q7. Call/Visit Date                                                                                 5786 non-null   object
#  6   Call Hour                                                                                           5786 non-null   int64
#  7   Call Minute                                                                                         5785 non-null   float64
#  8   Call Type                                                                                           5771 non-null   object
#  9   Q9. Type of call                                                                                    1230 non-null   object
#  10  Q10. TeleCaller/Data Collector ID                                                                   5786 non-null   object
#  11  Q11. Who is Respondent                                                                              1233 non-null   object
#  12  Q12. Respondent Other (Relation with newborn baby)                                                  0 non-null      float64
#  13  Q13. Respondent Name                                                                                143 non-null    object
#  14  Q14. Name of Mother                                                                                 5786 non-null   object
#  15  Q15. Name of Father                                                                                 5786 non-null   object
#  16  Q16. Family Mobile Number                                                                           5764 non-null   float64
#  17  Q17. Family 2nd Mobile Number                                                                       5785 non-null   float64
#  18  Resident type                                                                                       5258 non-null   object
#  19  Block / Taluk Name                                                                                  5258 non-null   object
#  20  GP Name / Ward Name                                                                                 5258 non-null   object
#  21  ASHA/USHA Mobile No.                                                                                5258 non-null   object
#  22  Village Name                                                                                        4188 non-null   object
#  23  Q20. Mohalla/Society/Sector/Building Name                                                           898 non-null    object
#  24  Q21. House No (optional)                                                                            51 non-null     object
#  25  Q22. Is the mother a domicile of the district [district_name] (Optional)?                           884 non-null    object
#  26  Q22.1. If No, please specify the permanent address (Only for out of study area cases)               520 non-null    object
#  27  Q27. Status of mother at discharge                                                                  5786 non-null   object
#  28  Q28. If mother died, Date of death                                                                  0 non-null      float64
#  29  Q29. Status of mother at the time of birth notification                                             5785 non-null   object
#  30  Q30. If mother died, Date of death                                                                  0 non-null      float64
#  31  Q31. Do you know the LMP Date?                                                                      5786 non-null   object
#  32  Q32. LMP Date (dd/mm/yyyy)                                                                          5777 non-null   object
#  33  Q33. Delivery Date                                                                                  5786 non-null   object
#  34  Delievery Time Hours                                                                                5765 non-null   float64
#  35  Delivery Time Minute                                                                                5765 non-null   float64
#  36  Delievery Time Type                                                                                 5744 non-null   object
#  37  Q35. Gestation Age (in weeks)                                                                       5777 non-null   float64
#  38  Q36.  Clinically estimated Gestation Age (in completed weeks)                                       0 non-null      float64
#  39  Q37. Is an Ultrasound report available ( done before 20 weeks of gestation)?                        4948 non-null   object
#  40   Q38. If available, what is the EDD mentioned in the document (done before 20 weeks of gestation)?  0 non-null      float64
#  41  Q38a. Gestation Age as calculated through EDD by ultrasound.                                        0 non-null      float64
#  42  Q39. Delivery type                                                                                  5786 non-null   object
#  43  Q40. If Assisted Vaginal Delivery, Specify (optional)                                               0 non-null      float64
#  44  Q41. Delivery Location                                                                              5785 non-null   object
#  45  Q42. If health facility, Delivery Place name (Private)                                              1460 non-null   object
#  46  Q43. If health facility, Delivery Place name (Public)                                               4192 non-null   object
#  47  Q44. Other/ Delivery outside the district                                                           461 non-null    object
#  48  Q45. Number of baby delivered                                                                       5786 non-null   object
#  49  Q47. Baby-1 : What was the status of the baby at birth?                                             5786 non-null   object
#  50  Q48. Baby-1 : Sex of the baby                                                                       5786 non-null   object
#  51  Q49. Baby-1 : Birth weight of the baby (grams)                                                      5775 non-null   float64
#  52  Q50. Baby-1: Baby Current Status (at the time of notification)                                      5730 non-null   object
#  53  Q51. Baby-1 : If died, then Date of death of Newborn (dd/mm/yyyy)                                   15 non-null     object
#  54  Q53. Baby-2 : What was the status of the baby at birth?                                             49 non-null     object
#  55  Q54. Baby-2 : Sex of the baby                                                                       49 non-null     object
#  56  Q55. Baby-2 : Birth weight of the baby (grams)                                                      48 non-null     float64
#  57  Q56. Baby-2 : Baby Current Status (at the time of notification)                                     49 non-null     object
#  58  Q57. Baby-2 : If died, then Date of death of Newborn (dd/mm/yyyy)                                   1 non-null      object
#  59  Q59. Baby-3: What was the status of the baby at birth?                                              0 non-null      float64
#  60  Q60. Baby-3 : Sex of the baby                                                                       0 non-null      float64
#  61  Q61. Baby-3 : Birth weight of the baby (grams)                                                      0 non-null      float64
#  62  Q62. Baby-3: Baby Current Status (at the time of notification)                                      0 non-null      float64
#  63  Q63. Baby-3 : If died, then Date of death of Newborn (dd/mm/yyyy)                                   0 non-null      float64
#  64  BabyAge                                                                                             5786 non-null   int64
#  65  Q64. Remarks                                                                                        1802 non-null   object
#  66  Complete?                                                                                           5786 non-null   object
# dtypes: float64(21), int64(2), object(44)
# memory usage: 3.0+ MB
# None

# %%
# Display the first few rows and information about the second DataFrame
print("DataFrame 2 - BirthNotificationBy Asha_2025-08-19.csv")
print(df2.head())
print(df2.info())
# Out:
# DataFrame 2 - BirthNotificationBy Asha_2025-08-19.csv
#    Q1.RecordID         Event Name Q1. Data Collected From  \
# 0         6949  BirthNotification     Asha (through call)
# 1         6950  BirthNotification     Asha (through call)
# 2         6951  BirthNotification     Asha (through call)
# 3         6952  BirthNotification     Asha (through call)
# 4         6953  BirthNotification     Asha (through call)
#
#    Q2. Name of the facility where the data was collected    \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Q2.1 Other Facility Name Q3. Call/Visit Date  Call Hour  Call Minute  \
# 0                       NaN          25-07-2025         12           45
# 1                       NaN          25-07-2025         12           48
# 2                       NaN          25-07-2025         12           51
# 3                       NaN          25-07-2025         12           53
# 4                       NaN          25-07-2025         12           54
#
#   Call Time Type  Q4. Type of call  ... Q30b. Baby-2 : Sex of the baby  \
# 0              PM         Outbound  ...                            NaN
# 1              PM         Outbound  ...                            NaN
# 2              PM         Outbound  ...                            NaN
# 3              PM         Outbound  ...                            NaN
# 4              PM         Outbound  ...                            NaN
#
#   Q31b. Baby-2 : Birth weight of the baby (grams)    \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    Q32b. Baby-2 : Baby Current Status  (On the day of data collection)    \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Q33b. Baby-2 : If died, then Date of death of Newborn (dd/mm/yyyy)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Q29c. Baby-3 : What was the status of the baby at birth?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Q30c. Baby-3 : Sex of the baby  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#
#    Q31c. Baby-3 : Birth weight of the baby (grams)    \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Q32c. Baby-3 : Baby Current Status  (On the day of data collection)    \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Q33c. Baby-3 : If died, then Date of death of Newborn (dd/mm/yyyy)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Complete?
# 0   Complete
# 1   Complete
# 2   Complete
# 3   Complete
# 4   Complete
#
# [5 rows x 62 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423 entries, 0 to 422
# Data columns (total 62 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   Q1.RecordID                                                            423 non-null    int64
#  1   Event Name                                                             423 non-null    object
#  2   Q1. Data Collected From                                                423 non-null    object
#  3   Q2. Name of the facility where the data was collected                  0 non-null      float64
#  4   Q2.1 Other Facility Name                                               0 non-null      float64
#  5   Q3. Call/Visit Date                                                    423 non-null    object
#  6   Call Hour                                                              423 non-null    int64
#  7   Call Minute                                                            423 non-null    int64
#  8   Call Time Type                                                         423 non-null    object
#  9   Q4. Type of call                                                       390 non-null    object
#  10  Q5.TeleCaller/Data Collector ID                                        423 non-null    object
#  11  Q6. Who is Respondent                                                  390 non-null    object
#  12  Q7. Respondent Other (Relation with newborn baby)                      0 non-null      float64
#  13  Q8. Respondent Name                                                    380 non-null    object
#  14  Q9. Name of Mother                                                     423 non-null    object
#  15  Q10. Name of Father                                                    423 non-null    object
#  16  Q11. Family Mobile Number                                              362 non-null    float64
#  17  Q12. Family 2nd Mobile Number                                          403 non-null    float64
#  18  Q13. District Name                                                     388 non-null    object
#  19  13a. Please Specify Other District Name                                0 non-null      float64
#  20  Q13.1 Other District Address                                           0 non-null      float64
#  21  Q14. Resident Type                                                     388 non-null    object
#  22  Q15. Block Name                                                        363 non-null    object
#  23  Q16. GPName                                                            361 non-null    object
#  24  Q16.1 Please Specify Other GPName                                      0 non-null      float64
#  25  Q17. VillageName                                                       360 non-null    object
#  26  Q17.1 Please Specify Other Village Name                                0 non-null      float64
#  27  Q18. Mohalla/Society/Sector/Building Name                              25 non-null     object
#  28  Q18.1. Ward                                                            24 non-null     object
#  29  Q18.2 HouseNo                                                          3 non-null      object
#  30  Q18.3 Landmark                                                         13 non-null     object
#  31  AshaName-Mobileno                                                      359 non-null    object
#  32  Q21. Other ASHA/USHA name                                              25 non-null     object
#  33  Q22. Other ASHA/USHA Mobile No.                                        25 non-null     float64
#  34  Q23. Status of mother at discharge                                     419 non-null    object
#  35  Q23.1 Current Status of Mother                                         419 non-null    object
#  36  Q24. Delivery Date                                                     423 non-null    object
#  37  Delievery Time Hours                                                   393 non-null    float64
#  38  Delivery Time Minute                                                   393 non-null    float64
#  39  Q25. Delievery Time Type                                               393 non-null    object
#  40  Q25.1. Delivery type                                                   422 non-null    object
#  41  Q26. Delivery Location                                                 421 non-null    object
#  42  Q27. If health facility, Delivery Place name (Private)                 48 non-null     object
#  43  Q27.1. If health facility, Delivery Place name (Public)                303 non-null    object
#  44  Q27a.  Delivery Place name other (not in List)                         41 non-null     object
#  45  Q28. Number of baby delivered                                          423 non-null    object
#  46  Q29a. Baby-1 : What was the status of the baby at birth?               423 non-null    object
#  47  Q30a. Baby-1 : Sex of the baby                                         423 non-null    object
#  48  Q31a. Baby-1 : Birth weight of the baby (grams)                        417 non-null    float64
#  49  Q32a. Baby-1 : Baby Current Status (On the day of data collection)     423 non-null    object
#  50  Q33a. Baby-1 : If died, then Date of death of Newborn (dd/mm/yyyy)     9 non-null      object
#  51  Q29b. Baby-2 : What was the status of the baby at birth?               6 non-null      object
#  52  Q30b. Baby-2 : Sex of the baby                                         6 non-null      object
#  53  Q31b. Baby-2 : Birth weight of the baby (grams)                        6 non-null      float64
#  54  Q32b. Baby-2 : Baby Current Status  (On the day of data collection)    6 non-null      object
#  55  Q33b. Baby-2 : If died, then Date of death of Newborn (dd/mm/yyyy)     1 non-null      object
#  56  Q29c. Baby-3 : What was the status of the baby at birth?               0 non-null      float64
#  57  Q30c. Baby-3 : Sex of the baby                                         0 non-null      float64
#  58  Q31c. Baby-3 : Birth weight of the baby (grams)                        0 non-null      float64
#  59  Q32c. Baby-3 : Baby Current Status  (On the day of data collection)    0 non-null      float64
#  60  Q33c. Baby-3 : If died, then Date of death of Newborn (dd/mm/yyyy)     0 non-null      float64
#  61  Complete?                                                              423 non-null    object
# dtypes: float64(19), int64(3), object(40)
# memory usage: 205.0+ KB
# None

# %%
# Clean column names by stripping whitespace
df1.columns = df1.columns.str.strip()
df2.columns = df2.columns.str.strip()

# %%
# Define meaningful combinations of columns for finding duplicates
combinations_to_check = [
    {
        'name': 'Mother Father Name, Mobile, Delivery Date, and Village',
        'df1_cols': ['Q14. Name of Mother', 'Q15. Name of Father', 'Q16. Family Mobile Number', 'Q33. Delivery Date', 'Village Name'],
        'df2_cols': ['Q9. Name of Mother', 'Q10. Name of Father', 'Q11. Family Mobile Number', 'Q24. Delivery Date', 'Q17. VillageName']
    },
    {
        'name': 'Mother Father Name, Mobile and Delivery Date',
        'df1_cols': ['Q14. Name of Mother', 'Q15. Name of Father', 'Q16. Family Mobile Number', 'Q33. Delivery Date'],
        'df2_cols': ['Q9. Name of Mother', 'Q10. Name of Father', 'Q11. Family Mobile Number', 'Q24. Delivery Date']
    },
    {
        'name': 'Mother Father Name and Mobile',
        'df1_cols': ['Q14. Name of Mother', 'Q15. Name of Father', 'Q16. Family Mobile Number'],
        'df2_cols': ['Q9. Name of Mother', 'Q10. Name of Father', 'Q11. Family Mobile Number']
    },
    {
        'name': 'Mother Father Name and Delivery Date',
        'df1_cols': ['Q14. Name of Mother', 'Q15. Name of Father', 'Q33. Delivery Date'],
        'df2_cols': ['Q9. Name of Mother', 'Q10. Name of Father', 'Q24. Delivery Date']
    },
    {
        'name': 'Mobile Number and Delivery Date',
        'df1_cols': ['Q16. Family Mobile Number', 'Q33. Delivery Date'],
        'df2_cols': ['Q11. Family Mobile Number', 'Q24. Delivery Date']
    }
]

# %%
# List to hold all duplicate dataframes for later concatenation
all_duplicates_list = []

# %%
# Loop through each combination and find duplicates
for i, combo in enumerate(combinations_to_check):
    print(f"Processing combination {i+1}: {combo['name']}")

    # Make copies to work with inside the loop
    df1_temp = df1.copy()
    df2_temp = df2.copy()

    # Standardize data types for a cleaner merge
    for col in combo['df1_cols']:
        if 'Mobile Number' in col:
            df1_temp[col] = df1_temp[col].astype(str)
        elif 'Date' in col:
            df1_temp[col] = pd.to_datetime(df1_temp[col], errors='coerce')

    for col in combo['df2_cols']:
        if 'Mobile Number' in col:
            df2_temp[col] = df2_temp[col].astype(str)
        elif 'Date' in col:
            df2_temp[col] = pd.to_datetime(df2_temp[col], errors='coerce')

    # Perform an inner merge to find common rows
    merged_duplicates = pd.merge(df1_temp, df2_temp, how='inner', left_on=combo['df1_cols'], right_on=combo['df2_cols'], suffixes=('_df1', '_df2'))

    # Save the individual duplicate file
    output_filename = f"duplicates_combo_{i+1}.csv"
    merged_duplicates.to_csv(output_filename, index=False)
    print(f"  Found {len(merged_duplicates)} duplicate rows. Saved to '{output_filename}'")

     # Add the current merged DataFrame to the master list
    all_duplicates_list.append(merged_duplicates)
# Out:
# Processing combination 1: Mother Father Name, Mobile, Delivery Date, and Village
#   Found 0 duplicate rows. Saved to 'duplicates_combo_1.csv'
# Processing combination 2: Mother Father Name, Mobile and Delivery Date
#   Found 2 duplicate rows. Saved to 'duplicates_combo_2.csv'
# Processing combination 3: Mother Father Name and Mobile
#   Found 3 duplicate rows. Saved to 'duplicates_combo_3.csv'
# Processing combination 4: Mother Father Name and Delivery Date
#   Found 12 duplicate rows. Saved to 'duplicates_combo_4.csv'
# Processing combination 5: Mobile Number and Delivery Date
#   Found 476 duplicate rows. Saved to 'duplicates_combo_5.csv'

# %%
# Concatenate all the individual duplicate dataframes and remove duplicates
if all_duplicates_list:
    final_all_duplicates = pd.concat(all_duplicates_list, ignore_index=True)
    
    # Drop duplicates based on the most robust key combination
    cols_to_drop_on = ['Q14. Name of Mother', 'Q15. Name of Father', 'Q16. Family Mobile Number', 'Q33. Delivery Date']
    final_all_duplicates.drop_duplicates(subset=cols_to_drop_on, inplace=True)
    
    # Save the final file with all unique duplicates
    final_output_filename = "all_unique_duplicates.csv"
    final_all_duplicates.to_csv(final_output_filename, index=False)
    print(f"\nTotal unique duplicates across all combinations found: {len(final_all_duplicates)}. Saved to '{final_output_filename}'")
else:
    print("\nNo duplicates found in any combination.")
# Out:
# Total unique duplicates across all combinations found: 150. Saved to 'all_unique_duplicates.csv'
